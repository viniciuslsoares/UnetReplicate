# %%
# !python -m minerva.pipelines.lightning_pipeline --config configs/pipelines/lightning_pipeline/efficient_unet_f3_train.yaml --print_config
# Out:
# model:
#   class_path: minerva.models.nets.EfficientUnet.EfficientUnet
#   init_args:
#     n_channels: 2
#     n_classes: 6
#     learning_rate: 0.001
#     bilinear: false
#     loss_fn: null
#     train_metrics:
#       mIoU:
#         class_path: torchmetrics.JaccardIndex
#         init_args:
#           task: multiclass
#           threshold: 0.5
#           num_classes: 6
#           num_labels: null
#           average: macro
#           ignore_index: null
#           validate_args: true
#           compute_on_cpu: false
#           dist_sync_on_step: false
#           sync_on_compute: true
#           compute_with_cache: true
#     val_metrics:
#       mIoU:
#         class_path: torchmetrics.JaccardIndex
#         init_args:
#           task: multiclass
#           threshold: 0.5
#           num_classes: 6
#           num_labels: null
#           average: macro
#           ignore_index: null
#           validate_args: true
#           compute_on_cpu: false
# ...

# %%
# !python -m minerva.pipelines.lightning_pipeline --config configs/pipelines/lightning_pipeline/efficient_unet_f3_train.yaml
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Log directory set to: /workspace/Minerva-Workshop/lightning_logs/version_25
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type             | Params
# ----------------------------------------------
# 0 | backbone | _EfficientUnet   | 2.3 M
# 1 | fc       | Identity         | 0
# 2 | loss_fn  | CrossEntropyLoss | 0
# ----------------------------------------------
# 2.3 M     Trainable params
# 0         Non-trainable params
# 2.3 M     Total params
# 9.181     Total estimated model params size (MB)
# Epoch 0:  70%|███████████████▎      | 690/992 [00:13<00:05, 51.73it/s, v_num=25]^C
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/trainer/call.py:54: Detected KeyboardInterrupt, attempting graceful shutdown...
# ...
